# %%
import numpy as np
import os
import h5py, pickle
from itertools import permutations
from sympy.combinatorics import Permutation


path='/nvme/h/cy22yl1/projectData/05_moments/cB211.072.64/data_merge/conn_0,0,0,0,0,0.h5'
with h5py.File(path) as f:
    print(f['inserts'][:])
    t=f['data/j+;conn_10'][0,5,0,0,:]
    print(t)
    t=t[[0,4,7,9]]
    print(t)
    print(np.sum(t))
# Out:
# [b'tt' b'tx' b'ty' b'tz' b'xx' b'xy' b'xz' b'yy' b'yz' b'zz']
# [-1.27199265e-10+2.32155059e-11j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   4.23997434e-11-7.73849734e-12j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  4.23997434e-11-7.73849734e-12j
#   0.00000000e+00+0.00000000e+00j  4.23997434e-11-7.73849734e-12j]
# [-1.27199265e-10+2.32155059e-11j  4.23997434e-11-7.73849734e-12j
#   4.23997434e-11-7.73849734e-12j  4.23997434e-11-7.73849734e-12j]
# (-3.469446953246084e-17+1.3877787807814457e-17j)

# %%
path='/nvme/h/cy22yl1/projectData/02_discNJN_1D/data_conn/B64.h5'
with h5py.File(path) as f:
    t=f['data/j+;conn_10'][0,5,0,0,:]
    print(t)
    print(t[[0,4,7,9]])
    print(np.sum(t[[0,4,7,9]]))
# Out:
# [-1.27199258e-10+2.32155024e-11j  1.61316403e-12+2.66104500e-11j
#   1.29823097e-11+1.83224998e-11j  2.54866649e-11-1.47899644e-11j
#   3.96468899e-11-8.04428399e-12j  2.35649052e-11-8.75399666e-12j
#   2.76632276e-12+1.29619744e-11j  5.86259027e-11-4.12464160e-12j
#  -9.45838373e-12+1.66906437e-11j  2.89264654e-11-1.10465768e-11j]
# [-1.27199258e-10+2.32155024e-11j  3.96468899e-11-8.04428399e-12j
#   5.86259027e-11-4.12464160e-12j  2.89264654e-11-1.10465768e-11j]
# 0j
