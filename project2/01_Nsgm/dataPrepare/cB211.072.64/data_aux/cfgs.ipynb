# %%
import h5py,os,re,click
import numpy as np

path='/capstor/store/cscs/userlab/s1174/lyan/code/projectData/NST_f_discBCD/cB211.072.64'
cfgs_N=[cfg[:5] for cfg in os.listdir(path)]

# path=''
# Out:
# ['b1332',
#  'b0736',
#  'b0988',
#  'a0544',
#  'b0772',
#  'a1036',
#  'b0040',
#  'a1260',
#  'b0076',
#  'b0776',
#  'a1948',
#  'b0652',
#  'a1152',
#  'b1148',
#  'a1724',
#  'a1640',
#  'a1264',
#  'a1972',
#  'b0360',
#  'b0628',
#  'b0152',
#  'b0396',
#  'a1960',
#  'a0632',
#  'b0348',
#  'b0732',
#  'b0500',
#  'a1000',
#  'b1004',
#  'b0524',
#  'a1828',
#  'a1680',
#  'b1064',
#  'b1244',
#  'b0536',
#  'a1076',
#  'b0660',
#  'a1048',
#  'a1932',
#  'b0368',
#  'b0956',
#  'a0820',
#  'a0532',
#  'b0748',
#  'b1444',
#  'a1196',
#  'a1536',
#  'b0388',
#  'b0420',
#  'b0216',
#  'b0704',
#  'a1964',
#  'b0812',
#  'a1888',
#  'b0664',
#  'a1096',
#  'a0932',
#  'b1420',
#  'b1472',
#  'a1692',
#  'b0568',
#  'a1396',
#  'a1784',
#  'a1456',
#  'a0704',
#  'a1684',
#  'b1252',
#  'b0620',
#  'a1200',
#  'b0572',
#  'b0580',
#  'a1280',
#  'b0968',
#  'b1380',
#  'a1556',
#  'b1228',
#  'a1172',
#  'b0212',
#  'a0608',
#  'b0292',
#  'b0600',
#  'a1160',
#  'a1736',
# ...
